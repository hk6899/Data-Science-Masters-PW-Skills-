# %% [markdown]
# # Assignment Multiprocessing

# %% [markdown]
# Q1. What is multiprocessing in python? Why is it useful?

# %% [markdown]
# Multiprocessing refers to the ability of a system to support more than one processor at the same time. Applications in a multiprocessing system are broken to smaller routines that run independently. The operating system allocates these threads to the processors improving performance of the system.

# %% [markdown]
# Q2. What are the differences between multiprocessing and multithreading?

# %% [markdown]
# Multithreading : It Implements the Concurrency.Python does not support multithreading in the case of parallel computing.In multithreading, multiple threads at the same time are generated by a single process.
# Multiprocessig: It Implements the Parallelism. Python supports multiprocessing in the case of parallel computing. In multiprocessing, multiple threads at the same time run across multiple cores.

# %% [markdown]
# Q3. Write a python code to create a process using the multiprocessing module.

# %%
import multiprocessing
def display():
    print('hi')
if __name__ == "__main__":
    arr = [1,2,3,4,5]
    m = multiprocessing.Process(target = display)
    m.start()
# Out:
# hi

# %% [markdown]
# Q4. What is a multiprocessing pool in python? Why is it used?

# %% [markdown]
# Python multiprocessing Pool can be used for parallel execution of a function across multiple input values, distributing the input data across processes (data parallelism).

# %% [markdown]
# Q5. How can we create a pool of worker processes in python using the multiprocessing module?

# %%
def square(n):
    return n**2
if __name__ == "__main__":
    arr = [1,2,3,4,5]
    with multiprocessing.Pool(processes = 5) as pool:
        sq = pool.map(square,arr)
        print(sq)
# Out:
# [1, 4, 9, 16, 25]

# %% [markdown]
# Q6. Write a python program to create 4 processes, each process should print a different number using the
# multiprocessing module in python.

# %%
def square(n):
    return n**2
if __name__ == "__main__":
    arr = [1,2,3,4,5]
    with multiprocessing.Pool(processes = 5) as pool:
        sq = pool.map(square,arr)
        print(sq)

# %% [markdown]
# Q6. Write a python program to create 4 processes, each process should print a different number using the
# multiprocessing module in python.

# %%
import random
def cube(n):
    return n**3
if __name__ == "__main__":
    with multiprocessing.Pool(processes = 4) as pool:
        arr = [1,4,5,7]
        c = pool.map(cube,arr)
        print(c)
# Out:
# [1, 64, 125, 343]
